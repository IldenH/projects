# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("temperatur.csv")
df
# Out:
#          Tid  Temperatur
# 0      24.74     33.0625
# 1      31.25     23.2500
# 2      37.74     52.7500
# 3      44.23     75.7500
# 4      50.72     84.0625
# ..       ...         ...
# 676  4296.84     32.0000
# 677  4300.59     32.0000
# 678  4304.35     32.0000
# 679  4308.11     32.0000
# 680  4311.86     31.9375
#
# [681 rows x 2 columns]

# %%
df.plot(x="Tid", y="Temperatur", ylabel="Temperatur")
# Out:
# <Axes: xlabel='Tid', ylabel='Temperatur'>

# %%
df.plot(x="Tid", y="Temperatur", ylabel="Temperatur")
plt.xlim(100, 500)
plt.show()

# %%
df["Temperatur"].mean()
# Out:
# np.float64(48.31690528634361)

# %%
df["Temperatur"].max()
# Out:
# np.float64(91.5)

# %%
df["Temperatur"].min()
# Out:
# np.float64(23.25)

# %%
df["Temperatur"].median()
# Out:
# np.float64(43.5625)

# %%
df["Temperatur"].sum()
# Out:
# np.float64(32903.8125)

# %%
df["Tid"].min()
# Out:
# np.float64(24.74)

# %%
df["Tid"].max()
# Out:
# np.float64(4311.86)
